# %% [markdown]
# # Statistics Advance Part 1 Assignment

# %% [markdown]
# ## Theorical Question and Answers

# %% [markdown]
# 1.  What is a random variable in probability theory?
#    - In probability theory, a random variable is a variable that takes on different values based on the outcomes of a random phenomenon. It is used to quantify and analyze random events. There are two types of random variables: discrete and continuous. Discrete random variables take on a countable number of distinct values, often associated with events that can be counted, such as the number of heads in a series of coin flips. Continuous random variables take on an infinite number of possible values within a given range, associated with measurements that can take any value within a continuum, such as height or weight. Understanding random variables is essential for analyzing and interpreting data in probability and statistics.

# %% [markdown]
# 2.  What are the types of random variables?
#    - In probability theory, there are two main types of random variables: discrete and continuous.
#
#      ### Discrete Random Variables:
#       These variables take on a countable number of distinct values. They are often associated with events that can be counted, such as the number of heads in a series of coin flips or the number of customers arriving at a store.
#
#      ### Continuous Random Variables:
#       These variables take on an infinite number of possible values within a given range. They are associated with measurements that can take any value within a continuum, such as height, weight, or time.

# %% [markdown]
# 3. What is the difference between discrete and continuous distributions?
#    - Discrete and continuous distributions are two types of probability distributions that describe different kinds of random variables.
#
#       Discrete Distributions: These distributions describe discrete random variables, which take on a countable number of distinct values. The probability of each value is specified, and the sum of all probabilities is equal to 1. Examples include the binomial distribution and the Poisson distribution.
#
#       Continuous Distributions: These distributions describe continuous random variables, which take on an infinite number of possible values within a given range. The probability of any single value is zero; instead, probabilities are assigned to intervals of values. The total area under the probability density function (PDF) is equal to 1. Examples include the normal distribution and the exponential distribution.
#
#       Hence, discrete distributions deal with countable values, while continuous distributions deal with an infinite range of values within a continuum.

# %% [markdown]
# 4. What are probability distribution functions (PDF)?
#    - Probability distribution functions (PDFs) describe the likelihood of different outcomes for a random variable. For discrete random variables, the PDF is called the probability mass function (PMF), which gives the probability of each possible value. For continuous random variables, the PDF is a continuous function that describes the probability density over a range of values. The area under the PDF curve represents the probability of the random variable falling within that range. PDFs are essential tools in probability theory and statistics for understanding and analyzing the distribution of random variables.

# %% [markdown]
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#    - Cumulative distribution functions (CDF) and probability distribution functions (PDF) both describe the distribution of a random variable, but they serve different purposes. The PDF shows the probability density for specific values of a continuous random variable, with the area under the curve representing the probability of the variable falling within a specific range. In contrast, the CDF represents the cumulative probability that a random variable takes on a value less than or equal to a specific value, summing up the probabilities from the PDF. Essentially, while the PDF provides the probability density for individual values, the CDF shows the cumulative probability up to a certain value. Both functions are essential for understanding the distribution and behavior of random variables.

# %% [markdown]
# 6. What is a discrete uniform distribution?
#    - A discrete uniform distribution is a type of probability distribution where each possible outcome of a discrete random variable has an equal probability of occurring. In other words, all values in the range of the distribution are equally likely. This distribution is characterized by a finite number of equally spaced values. The discrete uniform distribution is useful in scenarios where each outcome is equally likely, such as in games of chance or random sampling.

# %% [markdown]
# 7.  What are the key properties of a Bernoulli distribution?
#    - The Bernoulli distribution is a discrete probability distribution that describes the outcome of a single trial with two possible outcomes: success (usually coded as 1) and failure (usually coded as 0). Here are the key properties of a Bernoulli distribution:
#
#      Two Outcomes: The distribution has only two possible outcomes, success and failure.
#
#      Probability of Success: The probability of success is denoted by
# 𝑝
# , where
# 0
# ≤
# 𝑝
# ≤
# 1
# .
#
#      Probability of Failure: The probability of failure is
# 1
# −
# 𝑝
# .
#
#      Mean: The mean (expected value) of the distribution is
# 𝑝
# .
#
#      Variance: The variance of the distribution is
# 𝑝
# (
# 1
# −
# 𝑝
# )
# .
#
#      These properties make the Bernoulli distribution a fundamental building block for more complex distributions, such as the binomial distribution.

# %% [markdown]
# 8. What is the binomial distribution, and how is it used in probability?
#    - The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, each with the same probability of success. It is characterized by two parameters: the number of trials (n) and the probability of success in each trial (p).
#
#       The binomial distribution is used in probability to calculate the likelihood of obtaining a specific number of successes in a given number of trials. It is commonly applied in scenarios such as quality control, medical testing, and survey analysis, where the outcomes can be classified as success or failure. By using the binomial distribution, we can determine the probability of different outcomes and make informed decisions based on the data.

# %% [markdown]
# 9. What is the Poisson distribution and where is it applied?
#    - The Poisson distribution is a discrete probability distribution that models the number of events occurring within a fixed interval of time or space, given that these events happen independently and at a constant average rate. It is characterized by the parameter λ (lambda), which represents the average number of events in the interval.
#
#      The Poisson distribution is commonly applied in scenarios where events occur randomly and independently, such as the number of customer arrivals at a store, the number of phone calls received at a call center, or the number of accidents at a traffic intersection. It is useful for modeling rare events and understanding the likelihood of different numbers of occurrences within a specified period or area.

# %% [markdown]
# 10.  What is a continuous uniform distribution?
#    - A continuous uniform distribution is a type of probability distribution where all outcomes within a specified range are equally likely. In other words, the probability density is constant across the entire range of possible values. This distribution is characterized by two parameters: the minimum value (a) and the maximum value (b). The probability density function (PDF) for a continuous uniform distribution is a horizontal line, indicating that every value between a and b has the same probability density. This distribution is often used in scenarios where each outcome within a range is equally likely, such as random sampling or modeling uncertainty within a specific interval.

# %% [markdown]
# 11. What are the characteristics of a normal distribution?
#    - The normal distribution, also known as the Gaussian distribution, is a continuous probability distribution that is symmetrical and bell-shaped. It is characterized by its mean  and standard deviation . Here are some key properties of the normal distribution:
#
#      Symmetry: The distribution is perfectly symmetrical around the mean, meaning the left and right sides are mirror images.
#
#      Mean, Median, and Mode: In a normal distribution, the mean, median, and mode are all equal and located at the center of the distribution.
#
#      Bell Shape: The distribution has a bell-shaped curve, with most of the data points concentrated around the mean and fewer data points as you move away from the mean.
#
#      Asymptotic: The tails of the distribution approach, but never touch, the horizontal axis.
#
#      These characteristics make the normal distribution a fundamental concept in statistics, widely used in various fields such as finance, psychology, and natural sciences.

# %% [markdown]
# 12. What is the standard normal distribution, and why is it important?
#    - The standard normal distribution is a special case of the normal distribution where the mean  is 0 and the standard deviation  is 1. It is important because it serves as a reference point for comparing other normal distributions. By converting any normal distribution to the standard normal distribution using a process called standardization (or z-score transformation), we can easily calculate probabilities and make inferences. The standard normal distribution is widely used in statistics for hypothesis testing, confidence intervals, and other analyses, making it a fundamental tool in the field.

# %% [markdown]
# 13.  What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#    - The Central Limit Theorem (CLT) is a fundamental principle in statistics that states that the distribution of the sample mean of a sufficiently large number of independent, identically distributed random variables will approximate a normal distribution, regardless of the original distribution of the variables. This theorem is critical because it allows statisticians to make inferences about population parameters using sample data. It underpins many statistical methods, including hypothesis testing and confidence intervals, by enabling the use of the normal distribution as an approximation for the sampling distribution of the sample mean. The CLT provides a foundation for making reliable and accurate predictions based on sample data, even when the underlying population distribution is unknown.

# %% [markdown]
# 14.  How does the Central Limit Theorem relate to the normal distribution?
#    - The Central Limit Theorem (CLT) is closely related to the normal distribution. It states that the distribution of the sample mean of a sufficiently large number of independent, identically distributed random variables will approximate a normal distribution, regardless of the original distribution of the variables. This means that even if the underlying population distribution is not normal, the sampling distribution of the sample mean will tend to be normal as the sample size increases. The CLT allows statisticians to use the normal distribution as an approximation for the sampling distribution of the sample mean, making it easier to perform hypothesis testing, construct confidence intervals, and make inferences about population parameters.

# %% [markdown]
# 15.  What is the application of Z statistics in hypothesis testing?
#    - Z statistics, or Z-scores, are used in hypothesis testing to determine whether to reject the null hypothesis. They measure the number of standard deviations a data point is from the mean. In hypothesis testing, Z-scores help compare the sample mean to the population mean when the population standard deviation is known. By converting the sample mean to a Z-score, we can use the standard normal distribution to calculate the probability of observing a value as extreme as the sample mean. This helps determine the p-value, which indicates the likelihood of obtaining the observed result under the null hypothesis. If the p-value is less than the significance level (usually 0.05), we reject the null hypothesis, suggesting that the observed result is statistically significant.

# %% [markdown]
# 16. How do you calculate a Z-score, and what does it represent?
#    - A Z-score, also known as a standard score, measures how many standard deviations a data point is from the mean of a dataset. It helps to understand the position of a data point within a distribution. To calculate a Z-score, you use the formula:
#        Z = 𝑋-𝜇/σ
#
#       Where:
#
#        : 𝑍
#  is the Z-score,
#
#        : 𝑋
#  is the value of the data point,
#
#         : 𝜇
#  is the mean of the dataset,
#
#         : 𝜎
#  is the standard deviation of the dataset.
#
#        The Z-score represents the relative position of a data point within the distribution. A positive Z-score indicates that the data point is above the mean, while a negative Z-score indicates that it is below the mean. A Z-score of 0 means the data point is exactly at the mean. This standardization allows for comparison between different datasets and is widely used in hypothesis testing and other statistical analyses.

# %% [markdown]
# 17.  What are point estimates and interval estimates in statistics?
#    - In statistics, point estimates and interval estimates are used to infer population parameters based on sample data. A point estimate is a single value that serves as an estimate of a population parameter, such as the sample mean used to estimate the population mean. An interval estimate, on the other hand, provides a range of values within which the population parameter is likely to fall. This range is typically expressed as a confidence interval, which gives an upper and lower bound along with a confidence level (e.g., 95%). Point estimates provide a specific value, while interval estimates offer a range that accounts for the uncertainty inherent in sampling.

# %% [markdown]
# 18.  What is the significance of confidence intervals in statistical analysis?
#    - Confidence intervals are crucial in statistical analysis because they provide a range of values within which a population parameter is likely to fall, along with a specified level of confidence (e.g., 95%). This range accounts for the uncertainty inherent in sampling and offers a more comprehensive understanding of the parameter than a single point estimate. Confidence intervals help researchers and analysts make informed decisions, assess the precision of their estimates, and evaluate the reliability of their results. They are widely used in hypothesis testing, survey analysis, and various fields to draw meaningful conclusions from sample data.

# %% [markdown]
# 19.  What is the relationship between a Z-score and a confidence interval?
#    - A Z-score and a confidence interval are closely related in statistical analysis. A Z-score measures how many standard deviations a data point is from the mean, while a confidence interval provides a range of values within which a population parameter is likely to fall. When constructing a confidence interval, Z-scores are used to determine the critical values that define the interval's boundaries. For example, in a 95% confidence interval, the Z-scores corresponding to the 2.5th and 97.5th percentiles of the standard normal distribution are used to calculate the interval's lower and upper bounds. This relationship allows us to use Z-scores to create confidence intervals and make inferences about population parameters based on sample data.

# %% [markdown]
# 20. How are Z-scores used to compare different distributions?
#    - Z-scores are used to standardize data points from different distributions, allowing for meaningful comparisons. By converting data points to Z-scores, we can measure how many standard deviations each point is from the mean of its respective distribution. This standardization enables us to compare data points from different distributions on a common scale, regardless of the original units or scales. For example, we can compare test scores from different exams or heights of individuals from different populations by converting them to Z-scores. This helps in identifying outliers, making inferences, and drawing conclusions across different datasets.

# %% [markdown]
# 21. What are the assumptions for applying the Central Limit Theorem?
#    - The Central Limit Theorem (CLT) relies on a few key assumptions to hold true:
#
#      : Independence: The random variables must be independent of each other.
#
#      : Identically Distributed: The random variables should be identically distributed, meaning they come from the same probability distribution.
#
#      : Sample Size: The sample size should be sufficiently large. While there's no strict rule, a common guideline is that a sample size of 30 or more is usually considered adequate.
#
#      These assumptions ensure that the distribution of the sample mean will approximate a normal distribution, regardless of the original distribution of the variables.

# %% [markdown]
# 22. What is the concept of expected value in a probability distribution?
#    - The expected value, also known as the mean, is a fundamental concept in probability distribution. It represents the long-term average or central value of a random variable. For a discrete random variable, the expected value is calculated by summing the products of each possible value and its corresponding probability. For a continuous random variable, it is calculated by integrating the product of the variable and its probability density function over the entire range. The expected value provides a measure of the central tendency of the distribution and is widely used in various fields, including finance, economics, and decision-making.

# %% [markdown]
# 23. How does a probability distribution relate to the expected outcome of a random variable?
#    - A probability distribution describes how the probabilities of different outcomes are distributed for a random variable. The expected outcome, or expected value, is a measure of the central tendency of this distribution. It represents the long-term average value of the random variable if the experiment were repeated many times. For discrete random variables, the expected value is calculated by summing the products of each possible value and its corresponding probability. For continuous random variables, it is calculated by integrating the product of the variable and its probability density function over the entire range. Essentially, the expected value provides a summary of the distribution, indicating the average outcome we can expect based on the probabilities of different values.

# %% [markdown]
# ## Practical Question and Answers

# %% [markdown]
# 1.  Write a Python program to generate a random variable and display its value.

# %%
# Ans

import random
# Generating a random variable
random_variable = random.random()
print("Random Variable:", random_variable)
# Out:
# Random Variable: 0.30057145547980424

# %% [markdown]
# 2.  Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
a = 1
b = 6
n = 1000
samples = np.random.randint(a, b + 1, size=n)
values, counts = np.unique(samples, return_counts=True)
pmf = counts / n
plt.stem(values, pmf, basefmt=" ")
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Probability Mass Function (PMF) of Discrete Uniform Distribution')
plt.show()

# %% [markdown]
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
# Ans

def bernoulli_pdf(p, x):
    """
    Calculate the PDF of a Bernoulli distribution.
    Parameters:
    p (float): Probability of success (0 <= p <= 1)
    x (int): Outcome (0 or 1)
    Returns:
    float: Probability of the outcome x
    """
    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1")
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1")

    return p if x == 1 else 1 - p
p = 0.5
x = 1
print("PDF of Bernoulli distribution:", bernoulli_pdf(p, x))
# Out:
# PDF of Bernoulli distribution: 0.5

# %% [markdown]
# 4.  Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
n = 10
p = 0.5
size = 1000
samples = np.random.binomial(n, p, size)
plt.hist(samples, bins=np.arange(n+2) - 0.5, density=True, edgecolor='black')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Histogram of Binomial Distribution (n=10, p=0.5)')
plt.xticks(range(n+1))
plt.show()

# %% [markdown]
# 5.  Create a Poisson distribution and visualize it using Python.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
lambda_ = 5
size = 1000
samples = np.random.poisson(lambda_, size)
plt.hist(samples, bins=range(min(samples), max(samples) + 2), density=True, edgecolor='black')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.title('Histogram of Poisson Distribution (λ=5)')
plt.show()

# %% [markdown]
# 6.  Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
a = 1
b = 6
n = 1000
samples = np.random.randint(a, b + 1, size=n)
values, counts = np.unique(samples, return_counts=True)
pmf = counts / n
cdf = np.cumsum(pmf)
plt.step(values, cdf, where='mid', label='CDF')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) of Discrete Uniform Distribution')
plt.legend()
plt.show()

# %% [markdown]
# 7.  Generate a continuous uniform distribution using NumPy and visualize it.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
a = 0
b = 1
n = 1000
samples = np.random.uniform(a, b, size=n)
plt.hist(samples, bins=30, density=True, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('Histogram of Continuous Uniform Distribution')
plt.show()

# %% [markdown]
# 8. Simulate data from a normal distribution and plot its histogram.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
mean = 0
std_dev = 1
size = 1000
samples = np.random.normal(mean, std_dev, size)
plt.hist(samples, bins=30, density=True, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('Histogram of Normal Distribution')
plt.show()

# %% [markdown]
# 9. Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
def calculate_z_scores(data):
    """
    Calculate Z-scores from a dataset.

    Parameters:
    data (array-like): The dataset

    Returns:
    array-like: Z-scores of the dataset
    """
    mean = np.mean(data)
    std_dev = np.std(data)
    z_scores = (data - mean) / std_dev
    return z_scores
def plot_z_scores(z_scores):
    """
    Plot Z-scores.

    Parameters:
    z_scores (array-like): Z-scores to plot
    """
    plt.hist(z_scores, bins=30, density=True, edgecolor='black')
    plt.xlabel('Z-score')
    plt.ylabel('Frequency')
    plt.title('Histogram of Z-scores')
    plt.show()
data = np.random.normal(0, 1, 1000)
z_scores = calculate_z_scores(data)
plot_z_scores(z_scores)

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
lambda_ = 1
sample_size = 30
num_samples = 1000
samples = np.random.exponential(1 / lambda_, (num_samples, sample_size))
sample_means = np.mean(samples, axis=1)
plt.hist(sample_means, bins=30, density=True, edgecolor='black')
plt.xlabel('Sample Mean')
plt.ylabel('Probability Density')
plt.title('Distribution of Sample Means (CLT Demonstration)')
plt.show()

# %% [markdown]
# 15. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
mean = 0
std_dev = 1
sample_size = 30
num_samples = 1000
samples = np.random.normal(mean, std_dev, (num_samples, sample_size))
sample_means = np.mean(samples, axis=1)
plt.hist(sample_means, bins=30, density=True, edgecolor='black')
plt.xlabel('Sample Mean')
plt.ylabel('Probability Density')
plt.title('Distribution of Sample Means (CLT Verification)')
plt.show()

# %% [markdown]
# 16.  Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
def plot_standard_normal_distribution():
    """
    Calculate and plot the standard normal distribution (mean = 0, std = 1).
    """
    x = np.linspace(-4, 4, 1000)
    y = (1 / np.sqrt(2 * np.pi)) * np.exp(-0.5 * x**2)
    plt.plot(x, y, label='Standard Normal Distribution')
    plt.xlabel('Value')
    plt.ylabel('Probability Density')
    plt.title('Standard Normal Distribution (mean = 0, std = 1)')
    plt.legend()
    plt.show()
plot_standard_normal_distribution()

# %% [markdown]
# 17.  Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
n = 10
p = 0.5
size = 1000
samples = np.random.binomial(n, p, size)
values, counts = np.unique(samples, return_counts=True)
probabilities = counts / size
plt.stem(values, probabilities, basefmt=" ")
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Probability Mass Function (PMF) of Binomial Distribution')
plt.show()

# %% [markdown]
# 18.  Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
def calculate_z_score(data_point, mean, std_dev):
    """
    Calculate the Z-score for a given data point.

    Parameters:
    data_point (float): The data point
    mean (float): The mean of the dataset
    std_dev (float): The standard deviation of the dataset
    Returns:
    float: Z-score of the data point
    """
    z_score = (data_point - mean) / std_dev
    return z_score
def plot_standard_normal_distribution():
    """
    Plot the standard normal distribution (mean = 0, std = 1).
    """
    x = np.linspace(-4, 4, 1000)
    y = (1 / np.sqrt(2 * np.pi)) * np.exp(-0.5 * x**2)
    plt.plot(x, y, label='Standard Normal Distribution')
    plt.xlabel('Value')
    plt.ylabel('Probability Density')
    plt.title('Standard Normal Distribution (mean = 0, std = 1)')
    plt.legend()
    plt.show()
data_point = 1.5
mean = 0
std_dev = 1
z_score = calculate_z_score(data_point, mean, std_dev)
print("Z-score of the data point:", z_score)
plot_standard_normal_distribution()
# Out:
# Z-score of the data point: 1.5

# %% [markdown]
# 19. Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
# Ans

import numpy as np
from scipy import stats
def hypothesis_testing(sample_data, population_mean, alpha=0.05):
    """
    Perform hypothesis testing using Z-statistics.
    Parameters:
    sample_data (array-like): The sample data
    population_mean (float): The population mean
    alpha (float): Significance level (default is 0.05)
    Returns:
    float: Z-score
    float: p-value
    bool: Whether to reject the null hypothesis
    """
    sample_mean = np.mean(sample_data)
    sample_std = np.std(sample_data, ddof=1)
    sample_size = len(sample_data)
    z_score = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))
    reject_null = p_value < alpha
    return z_score, p_value, reject_null
sample_data = np.random.normal(50, 10, 30)
population_mean = 55
alpha = 0.05
z_score, p_value, reject_null = hypothesis_testing(sample_data, population_mean, alpha)
print("Z-score:", z_score)
print("p-value:", p_value)
print("Reject the null hypothesis:", reject_null)
# Out:
# Z-score: -1.9259783234463337
# p-value: 0.054107080525031215
# Reject the null hypothesis: False

# %% [markdown]
# 20.  Create a confidence interval for a dataset using Python and interpret the result.

# %%
# Ans

import numpy as np
import scipy.stats as stats
def confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for a dataset.
    Parameters:
    data (array-like): The dataset
    confidence (float): The confidence level (default is 0.95)
    Returns:
    tuple: Lower and upper bounds of the confidence interval
    """
    mean = np.mean(data)
    std_err = stats.sem(data)
    margin_of_error = std_err * stats.t.ppf((1 + confidence) / 2, len(data) - 1)
    return mean - margin_of_error, mean + margin_of_error
data = np.random.normal(50, 10, 30)
confidence = 0.95
lower_bound, upper_bound = confidence_interval(data, confidence)
print(f"Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Confidence Interval: (48.36, 55.01)

# %% [markdown]
# 21. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
# Ans

import numpy as np
import scipy.stats as stats
def confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for a dataset.
    Parameters:
    data (array-like): The dataset
    confidence (float): The confidence level (default is 0.95)
    Returns:
    tuple: Lower and upper bounds of the confidence interval
    """
    mean = np.mean(data)
    std_err = stats.sem(data)
    margin_of_error = std_err * stats.t.ppf((1 + confidence) / 2, len(data) - 1)
    return mean - margin_of_error, mean + margin_of_error
mean = 50
std_dev = 10
size = 30
data = np.random.normal(mean, std_dev, size)
confidence = 0.95
lower_bound, upper_bound = confidence_interval(data, confidence)
print(f"Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
print(f"We are {confidence * 100}% confident that the true population mean lies between {lower_bound:.2f} and {upper_bound:.2f}.")
# Out:
# Confidence Interval: (47.19, 52.51)
# We are 95.0% confident that the true population mean lies between 47.19 and 52.51.

# %% [markdown]
# 22. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
def plot_normal_pdf(mean, std_dev):
    """
    Calculate and plot the PDF of a normal distribution.
    Parameters:
    mean (float): Mean of the distribution
    std_dev (float): Standard deviation of the distribution
    """
    x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
    y = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev)**2)
    plt.plot(x, y, label='Normal Distribution PDF')
    plt.xlabel('Value')
    plt.ylabel('Probability Density')
    plt.title('Probability Density Function (PDF) of Normal Distribution')
    plt.legend()
    plt.show()
mean = 0
std_dev = 1
plot_normal_pdf(mean, std_dev)

# %% [markdown]
# 23. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
def plot_poisson_cdf(lambda_, size):
    """
    Calculate and plot the CDF of a Poisson distribution.
    Parameters:
    lambda_ (float): Average rate (λ)
    size (int): Number of samples
    """
    samples = np.random.poisson(lambda_, size)
    values, counts = np.unique(samples, return_counts=True)
    cdf = np.cumsum(counts) / size
    plt.step(values, cdf, where='mid', label='Poisson CDF')
    plt.xlabel('Number of Events')
    plt.ylabel('Cumulative Probability')
    plt.title('Cumulative Distribution Function (CDF) of Poisson Distribution')
    plt.legend()
    plt.show()
lambda_ = 5
size = 1000
plot_poisson_cdf(lambda_, size)

# %% [markdown]
# 24.  Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
# Ans

import numpy as np
a = 0
b = 1
n = 1000
samples = np.random.uniform(a, b, size=n)
expected_value = np.mean(samples)
print("Expected Value:", expected_value)
# Out:
# Expected Value: 0.4755439109723982

# %% [markdown]
# 25. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
def compare_standard_deviations(data1, data2):
    """
    Compare the standard deviations of two datasets and visualize the difference.
    Parameters:
    data1 (array-like): The first dataset
    data2 (array-like): The second dataset
    """
    std_dev1 = np.std(data1, ddof=1)
    std_dev2 = np.std(data2, ddof=1)
    print(f"Standard Deviation of Dataset 1: {std_dev1:.2f}")
    print(f"Standard Deviation of Dataset 2: {std_dev2:.2f}")
    plt.hist(data1, bins=30, alpha=0.5, label='Dataset 1', edgecolor='black')
    plt.hist(data2, bins=30, alpha=0.5, label='Dataset 2', edgecolor='black')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Comparison of Standard Deviations')
    plt.legend()
    plt.show()
data1 = np.random.normal(50, 10, 1000)
data2 = np.random.normal(60, 15, 1000)
compare_standard_deviations(data1, data2)
# Out:
# Standard Deviation of Dataset 1: 10.10
# Standard Deviation of Dataset 2: 14.30

# %% [markdown]
# 26. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
# Ans

import numpy as np
mean = 50
std_dev = 10
size = 1000
data = np.random.normal(mean, std_dev, size)
data_range = np.ptp(data)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1
print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range: 61.68
# Interquartile Range (IQR): 13.77

# %% [markdown]
# 27.  Implement Z-score normalization on a dataset and visualize its transformation.

# %%
# Ans

import numpy as np
import matplotlib.pyplot as plt
def z_score_normalization(data):
    """
    Perform Z-score normalization on a dataset.
    Parameters:
    data (array-like): The dataset
    Returns:
    array-like: Normalized dataset
    """
    mean = np.mean(data)
    std_dev = np.std(data)
    normalized_data = (data - mean) / std_dev
    return normalized_data
def plot_data(original_data, normalized_data):
    """
    Plot the original and normalized datasets.
    Parameters:
    original_data (array-like): The original dataset
    normalized_data (array-like): The normalized dataset
    """
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.hist(original_data, bins=30, edgecolor='black')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Original Data')
    plt.subplot(1, 2, 2)
    plt.hist(normalized_data, bins=30, edgecolor='black')
    plt.xlabel('Z-score')
    plt.ylabel('Frequency')
    plt.title('Z-score Normalized Data')
    plt.tight_layout()
    plt.show()
data = np.random.normal(50, 10, 1000)
normalized_data = z_score_normalization(data)
plot_data(data, normalized_data)

# %% [markdown]
# 28. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
# distribution.

# %%
# Ans

import numpy as np
import scipy.stats as stats
def calculate_skewness_kurtosis(data):
    """
    Calculate the skewness and kurtosis of a dataset.
    Parameters:
    data (array-like): The dataset
    Returns:
    tuple: Skewness and kurtosis of the dataset
    """
    skewness = stats.skew(data)
    kurtosis = stats.kurtosis(data)
    return skewness, kurtosis
data = np.random.normal(0, 1, 1000)
skewness, kurtosis = calculate_skewness_kurtosis(data)
print(f"Skewness: {skewness:.2f}")
# Out:
# Skewness: 0.10
